# %% [markdown]
# <a href="https://colab.research.google.com/github/srushtinalawade-gif/Study-of-Pandas/blob/main/Practial9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Study of Pandas Library in Python
# ## Name: Srushti J. Nalawade
# ## PRN: 25070123157
# ##Batch: ENTC A1
# ## Experiment 9

# %%
import pandas as pd

s=pd.Series([10,20,30,40])
s
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
# Create DataFrame
data={"Name":['Srushti','Anvi','Prisha'],
      "Marks":[87,98,89]}

df=pd.DataFrame(data)
df
# Out:
#       Name  Marks
# 0  Srushti     87
# 1     Anvi     98
# 2   Prisha     89

# %% [markdown]
# df.head() is first 5 entries and df.tail() is last 5 entries

# %%
#Structure of DataFrame
df.shape
# Out:
# (3, 2)

# %%
df.ndim
# Out:
# 2

# %%
df.size
# Out:
# 6

# %%
#Display Column names
df.columns
# Out:
# Index(['Name', 'Marks'], dtype='object')

# %%
#Check data types of each column
df.dtypes
# Out:
# Name     object
# Marks     int64
# dtype: object

# %%
#Access Individual Column
df['Name']
# Out:
# 0    Srushti
# 1       Anvi
# 2     Prisha
# Name: Name, dtype: object

# %%
df['Marks']
# Out:
# 0    87
# 1    98
# 2    89
# Name: Marks, dtype: int64

# %%
#Access specific row
df.loc[1]
# Out:
# Name     Anvi
# Marks      98
# Name: 1, dtype: object

# %%
#Add a new column
df['Grade']=['A','A','A']
df
# Out:
#       Name  Marks Grade
# 0  Srushti     87     A
# 1     Anvi     98     A
# 2   Prisha     89     A

# %%
#Update Data in DataFrame
#Change marks of student
df.loc[0,'Marks']=100
df
# Out:
#       Name  Marks Grade
# 0  Srushti    100     A
# 1     Anvi     98     A
# 2   Prisha     89     A

# %%
from numpy import True_
#Delete a column
df.drop('Grade',axis=1,inplace=True)
df
# Out:
#       Name  Marks
# 0  Srushti    100
# 1     Anvi     98
# 2   Prisha     89

# %%
#Perform Basic Statistical Analysis
df['Marks'].mean()
# Out:
# np.float64(95.66666666666667)

# %%
df['Marks'].max()
# Out:
# 100

# %%
df['Marks'].min()
# Out:
# 89

# %%
#Apply Condition
df[df['Marks']>99]
# Out:
#       Name  Marks
# 0  Srushti    100
